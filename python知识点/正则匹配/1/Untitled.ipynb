# %%
import re

# %%
with open('script_content_37.txt', 'r', encoding='utf-8') as f:
    script_content = f.read()
script_content
# Out:
# '<?xml version="1.0" encoding="utf-8"?><ivrtree intention_logic="1"><catch event="nomatch" instruct="onhook" manual_pid=""><prompt bargein="true"><audio  mix_tts_id="16839" condition_id="0">不好意思，您说什么？</audio></prompt><prompt bargein="true"><audio  mix_tts_id="16840" condition_id="0">我这边没听清，您能说的慢一点吗？</audio></prompt><prompt ><audio  mix_tts_id="16841" condition_id="0">不好意思，我这边信号不太好，稍后由负责接待您的客户经理给您去电话，再见。</audio></prompt></catch><catch event="noinput" instruct="onhook"><prompt bargein="true"><audio  mix_tts_id="16842" condition_id="0">喂？您好？</audio></prompt><prompt bargein="true"><audio  mix_tts_id="16843" condition_id="0">请问您在听吗？</audio></prompt><prompt ><audio  mix_tts_id="16844" condition_id="0">不好意思，这边听不到您的声音，后期再与您联系，祝您生活愉快，再见。</audio></prompt></catch><catch event="maxquestions" instruct="onhook"><prompt max_time="6"><audio  mix_tts_id="16846" condition_id="0">我这边没听清，我们后期再与您联系</audio></prompt></catch><intention-type id="c33jy" type="A" priority="1" group_logic="or"><condition-group id="rxyo3" condition_logic="or"><label trigger="on" label_id="180" label_content="身份确认首轮否定" id="b3p7aa"/></condition-group></intention-type><intention-type id="832w1h" type="B" priority="2" group_logic="or"><condition-group id="6tnoln" condition_logic="or"><label trigger="on" label_id="180" label_content="辱骂" id="djxm0n"/><label trigger="on" label_id="180" label_content="投诉" id="4wwy2m"/></condition-group></intention-type><ivrnode id="8xqrk9ykl2587aatt9" type="root" default="false" noinput_default="false" instruct_manual_type="no" instruct_sms="false" instruct_product="false" process_end="false" allow_jump="true" collect_info="false" repeat_times="0" ivrnode_name="1身份确认首轮澄清" dialog_policy="question_first" ><prompt bargein="false" custom="false" realtime="false" ><audio  mix_tts_id="16822" condition_id="0">您好呀，我是您的众安小贷专属客服小王，来电呢是看到您还没有成功激活额度，您是在申请额度的过程中遇到了什么问题吗？</audio></prompt><choice next="5ji0v" default="false" noinput_default="false"></choice><choice next="xn902n" default="false" noinput_default="false"></choice><choice next="odyxv" default="true" noinput_default="true"></choice></ivrnode><ivrnode id="5ji0v" type="normal" cluster_id = "930,927" cluster_name = "贷款意图-否定3,不想继续了解3" default="false" noinput_default="false" label_id="180-36523_20221_30830_35748_39318_36718_21542_23450" label="身份确认首轮否定" instruct_manual_type="no" instruct_sms="false" instruct_product="false" process_end="false" allow_jump="true" collect_info="false" repeat_times="0" ivrnode_name="2告知来意首轮澄清" dialog_policy="question_first" ><prompt bargein="false" custom="false" realtime="false" ><audio  mix_tts_id="16613" condition_id="0">是这样的啊，您是我们的优质用户，给到您优先借款审批特权，提醒您尽快激活额度使用特权。现在平台还有新人首期免息活动，激活额度就可以参与了呢。因为我们每天的借款名额都是有限的，提醒您尽快使用哈</audio></prompt><choice next="zncrlm" default="false" noinput_default="false"></choice><choice next="fetk39" default="false" noinput_default="false"></choice><choice next="iv2lwj" default="true" noinput_default="true"></choice></ivrnode><ivrnode id="xn902n" type="normal" cluster_id = "931,929,928" cluster_name = "贷款意图-肯定3,有继续了解意愿3,无关紧要流程继续3" default="false" noinput_default="false" label_id="180-36523_20221_30830_35748_39318_36718_32943_23450" label="身份确认首轮肯定" instruct_manual_type="no" instruct_sms="false" instruct_product="false" process_end="false" allow_jump="true" collect_info="false" repeat_times="0" jump_ivrnode="zncrlm,fetk39,iv2lwj" ivrnode_name="2告知来意首轮澄清" dialog_policy="question_first" ><prompt bargein="false" custom="false" realtime="false" ><audio  mix_tts_id="16614" condition_id="0">是这样的啊，您是我们的优质用户，给到您优先借款审批特权，提醒您尽快激活额度使用特权。现在平台还有新人首期免息活动，激活额度就可以参与了呢。因为我们每天的借款名额都是有限的，提醒您尽快使用哈</audio></prompt></ivrnode><ivrnode id="odyxv" type="normal" cluster_id = "932" cluster_name = "通用拒识3" default="true" noinput_default="true" label_id="180-36523_20221_30830_35748_39318_36718_25298_35782_36229_26102_21548_19981_28165" label="身份确认首轮拒识超时听不清" instruct_manual_type="no" instruct_sms="false" instruct_product="false" process_end="false" allow_jump="true" collect_info="f ...

# %%
# pattern = re.compile(r'cluster_id ?= ?\"(\d+(?:,\d+)*)\"')
pattern = re.compile(r'cluster_id ?= ?\"(\d+(?:,\d+)*)\"')
pattern.findall(script_content)
# Out:
# ['930,927',
#  '931,929,928',
#  '932',
#  '927,930',
#  '928,929,931',
#  '932',
#  '930,927',
#  '931,928,929',
#  '822',
#  '930,927',
#  '931,929,928',
#  '932',
#  '930,929,928,927,931,932',
#  '822',
#  '930,927',
#  '931,929',
#  '822,928',
#  '930,927',
#  '931,929,928',
#  '822',
#  '930,927',
#  '931,929,928',
#  '932',
#  '930,927',
#  '931,929',
#  '822,928']
